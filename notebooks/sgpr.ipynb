# %%
import numpy as np
from matplotlib import pyplot as plt

import torchgp
from utils import get_data, plot_result

# %%
x_train, y_train, x_test, _ = get_data()

# %%
init_output_scale = 1.0
init_input_scale = 0.8
init_noise_variance = 0.001
num_pseudo = 10

# %%
x_pseudo = np.linspace(x_test.min(), x_test.max(), num_pseudo).reshape(-1, 1)
kernel = torchgp.kernels.GaussianKernel(input_scale=init_input_scale, output_scale=init_output_scale)
model = torchgp.models.SGPRModel(x_pseudo, kernel, noise_variance=init_noise_variance)

# %%
model.add_data(x_train, y_train)

# %% [markdown]
# ## Prediction Before Learning

# %%
mean, var = model.predict(x_test, include_likelihood=False)
fig, ax = plt.subplots(figsize=(8, 3))
plot_result(
    ax,
    x_train,
    y_train,
    x_test,
    mean,
    var,
    model.likelihood.noise_variance.item(),
    model.x_pseudo,
    model.f_pseudo,
)
ax.legend(
    loc="lower center",
    bbox_to_anchor=(0.5, -0.6),
    fancybox=True,
    shadow=True,
    ncol=6,
)
ax.grid()
ax.set_xlabel("x")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Prediction After Learning

# %%
model.learn()

# %%
mean, var = model.predict(x_test, include_likelihood=False)
fig, ax = plt.subplots(figsize=(8, 3))
plot_result(
    ax,
    x_train,
    y_train,
    x_test,
    mean,
    var,
    model.likelihood.noise_variance.item(),
    model.x_pseudo,
    model.f_pseudo,
)
ax.legend(
    loc="lower center",
    bbox_to_anchor=(0.5, -0.6),
    fancybox=True,
    shadow=True,
    ncol=6,
)
ax.grid()
ax.set_xlabel("x")
fig.tight_layout()
plt.show()

# %%
print(f"Noise variance of the Gaussian likelihood: {model.likelihood.noise_variance.item(): .2f}")
print(f"Input scale of the Gaussian kernel: {model.kernel.input_scale.item(): .2f}")
print(f"Output scale of the Gaussian kernel: {model.kernel.output_scale.item(): .2f}")
# Out:
# Noise variance of the Gaussian likelihood:  0.09
# Input scale of the Gaussian kernel:  1.74
# Output scale of the Gaussian kernel:  0.89
